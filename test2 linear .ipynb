# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("wine.csv")

# %%
data.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %%
data.columns =['class','Alcohol','Malic acid','Ash','Alcalinity of ash ','Magnesium','Total phenols','Flavanoids','Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

# %%
data
# Out:
#      class  Alcohol  Malic acid   Ash  Alcalinity of ash   Magnesium  \
# 0        1    13.20        1.78  2.14                11.2        100
# 1        1    13.16        2.36  2.67                18.6        101
# 2        1    14.37        1.95  2.50                16.8        113
# 3        1    13.24        2.59  2.87                21.0        118
# 4        1    14.20        1.76  2.45                15.2        112
# ..     ...      ...         ...   ...                 ...        ...
# 172      3    13.71        5.65  2.45                20.5         95
# 173      3    13.40        3.91  2.48                23.0        102
# 174      3    13.27        4.28  2.26                20.0        120
# 175      3    13.17        2.59  2.37                20.0        120
# 176      3    14.13        4.10  2.74                24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# ...

# %%
data.plot(kind='scatter',x='Alcohol',y='Ash')
plt.plot(Alcohol)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-cbcab986cf7b> in <module>
#       1 data.plot(kind='scatter',x='Alcohol',y='Ash')
# ----> 2 plt.plot(Alcohol)
#
# NameError: name 'Alcohol' is not defined

# %%
alco=pd.DataFrame(data["Alcohol"])

# %%
alco
# Out:
#      Alcohol
# 0      13.20
# 1      13.16
# 2      14.37
# 3      13.24
# 4      14.20
# ..       ...
# 172    13.71
# 173    13.40
# 174    13.27
# 175    13.17
# 176    14.13
#
# [177 rows x 1 columns]

# %%
As = pd.DataFrame(data["Ash"])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(alco,As,test_size=0.2)

# %%
x_train
# Out:
#      Alcohol
# 126    11.79
# 136    12.53
# 28     14.02
# 85     12.16
# 56     13.29
# ..       ...
# 123    11.87
# 77     12.33
# 33     13.51
# 81     12.08
# 158    13.48
#
# [141 rows x 1 columns]

# %%
from sklearn import linear_model,datasets
from sklearn.metrics import mean_squared_error

# %%
# Build linear regression model
ln=linear_model.LinearRegression()
model=ln.fit(x_train,y_train)

# %%
model.coef_
# Out:
# array([[0.07522543]])

# %%
data.corr()
# Out:
#                                  class   Alcohol  Malic acid       Ash  \
# class                         1.000000 -0.321238    0.436127 -0.048260
# Alcohol                      -0.321238  1.000000    0.099963  0.210964
# Malic acid                    0.436127  0.099963    1.000000  0.164955
# Ash                          -0.048260  0.210964    0.164955  1.000000
# Alcalinity of ash             0.513963 -0.303350    0.286148  0.446698
# Magnesium                    -0.198944  0.258742   -0.049049  0.287107
# Total phenols                -0.717933  0.284543   -0.333512  0.128176
# Flavanoids                   -0.846485  0.230133   -0.409324  0.114084
# Nonflavanoid phenols          0.487215 -0.151445    0.291501  0.187354
# Proanthocyanins              -0.494887  0.127561   -0.217975  0.008082
# Color intensity               0.268562  0.547883    0.250053  0.258643
# Hue                          -0.617690 -0.075375   -0.560854 -0.075181
# ...

# %%
model.intercept_
# Out:
# array([1.40728561])

# %%
model.score(x_train,y_train)
# Out:
# 0.05691952870534567

# %%
# testing part

y_pred=model.predict(x_test)
y_pred
# Out:
# array([[2.31600882],
#        [2.4514146 ],
#        [2.32879714],
#        [2.44991009],
#        [2.44840558],
#        [2.390482  ],
#        [2.47699124],
#        [2.33180616],
#        [2.39800454],
#        [2.4002613 ],
#        [2.33481518],
#        [2.37167564],
#        [2.32654038],
#        [2.39349101],
#        [2.28290963],
#        [2.43260824],
#        [2.39349101],
#        [2.38747298],
#        [2.43712176],
#        [2.32578813],
#        [2.42884697],
#        [2.47623899],
#        [2.39725229],
#        [2.2768916 ],
#        [2.4514146 ],
#        [2.35362154],
#        [2.46495517],
#        [2.34158547],
#        [2.44163529],
#        [2.29569795],
#        [2.42282893],
#        [2.34534674],
#        [2.29645021],
#        [2.42207668],
#        [2.3129998 ],
#        [2.37318015]])

# %%
# visualize the result

data.plot(kind="scatter",x='Alcohol',y='Malic acid')

plt.plot(x_train,model.predict(x_train),color='red',linewidth=2)

plt.plot(x_test,y_pred,color="black",linewidth=1)

# %%
xx = data.drop('Alcohol',axis = 'columns')

# %%
xx
# Out:
#      class  Malic acid   Ash  Alcalinity of ash   Magnesium  Total phenols  \
# 0        1        1.78  2.14                11.2        100           2.65
# 1        1        2.36  2.67                18.6        101           2.80
# 2        1        1.95  2.50                16.8        113           3.85
# 3        1        2.59  2.87                21.0        118           2.80
# 4        1        1.76  2.45                15.2        112           3.27
# ..     ...         ...   ...                 ...        ...            ...
# 172      3        5.65  2.45                20.5         95           1.68
# 173      3        3.91  2.48                23.0        102           1.80
# 174      3        4.28  2.26                20.0        120           1.59
# 175      3        2.59  2.37                20.0        120           1.65
# 176      3        4.10  2.74                24.5         96           2.05
#
# ...

# %%
yy = pd.DataFrame(data['Alcohol'])

# %%
yy
# Out:
#      Alcohol
# 0      13.20
# 1      13.16
# 2      14.37
# 3      13.24
# 4      14.20
# ..       ...
# 172    13.71
# 173    13.40
# 174    13.27
# 175    13.17
# 176    14.13
#
# [177 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
xx_train,xx_test,yy_train,yy_test = train_test_split(xx,yy,test_size=0.2,random_state=10)

# %%
xx_train
# Out:
#      class  Malic acid   Ash  Alcalinity of ash   Magnesium  Total phenols  \
# 95       2        2.12  2.74                21.5        134           1.60
# 91       2        1.53  2.26                20.7         80           1.38
# 24       1        2.05  3.22                25.0        124           2.63
# 109      2        3.74  1.82                19.5        107           3.18
# 121      2        4.43  2.73                26.5        102           2.20
# ..     ...         ...   ...                 ...        ...            ...
# 113      2        1.39  2.50                22.5         84           2.56
# 64       2        1.21  2.56                18.1         98           2.42
# 15       1        1.92  2.72                20.0        120           2.80
# 125      2        1.53  2.29                21.5         86           2.74
# 9        1        2.16  2.30                18.0        105           2.95
#
# ...

# %%
yy_test.head()
# Out:
#      Alcohol
# 69     12.29
# 103    12.51
# 20     12.93
# 116    12.42
# 56     13.29

# %%
from sklearn import linear_model,datasets

# %%
ln = linear_model.LinearRegression()

# %%
moddel = ln.fit(xx_train,yy_train)

# %%
yy_pred = moddel.predict(xx_test)

# %%
yy_pred
# Out:
# array([[12.73065925],
#        [12.39152641],
#        [13.6181073 ],
#        [11.89167374],
#        [13.89779423],
#        [12.35877523],
#        [12.83877718],
#        [13.44858634],
#        [13.44771152],
#        [13.76206584],
#        [13.35066829],
#        [12.5336628 ],
#        [13.69112079],
#        [12.53807726],
#        [12.15650441],
#        [12.60699712],
#        [12.30693707],
#        [12.28291209],
#        [12.10496947],
#        [13.36265032],
#        [13.74481702],
#        [12.85660408],
#        [13.72294738],
#        [14.02870951],
#        [12.59487436],
#        [12.78195942],
#        [12.366696  ],
#        [12.54432365],
#        [12.86828906],
#        [12.5631422 ],
#        [13.38111155],
#        [12.74649481],
#        [12.03410591],
#        [13.17167068],
#        [12.13475476],
#        [13.66383832]])

# %%
moddel.score(xx_train,yy_train)
# Out:
# 0.6567319534140222

# %%
moddel.score(xx_test,yy_pred)
# Out:
# 1.0

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-0a40b84fb293> in <module>
#       1 x=['Malic_acid','Ash']
# ----> 2 y=[data.Flavanoids.size(),data.Ash.size()]
#       3 plt.bar(x,y)
#
# TypeError: 'int' object is not callable
